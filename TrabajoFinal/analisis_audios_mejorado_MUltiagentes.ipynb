# %% [markdown]
# # Sistema de Transcripción y Análisis de Audios
#
# Este notebook permite ejecutar los agentes de transcripción y análisis de calidad, y visualizar las métricas generadas.
#
# ## Contenido
# 1. Configuración inicial
# 2. Agente de Transcripción
# 3. Visualización de Métricas de Transcripción
# 4. Agente de Auditoría de Calidad de Servicio al Cliente
# 5. Visualización de Métricas de Calidad
# 6. Reportes Consolidados

# %% [markdown]
# ## 1. Configuración Inicial

# %%
import logging
import sys

# 1. Obtenemos el logger raíz
logger = logging.getLogger()

# 2. Eliminamos configuraciones previas que puedan estar bloqueando la salida
for handler in logger.handlers[:]:
    logger.removeHandler(handler)

# 3. Configuramos la nueva salida hacia stdout (la consola del notebook)
logging.basicConfig(
    level=logging.INFO, # Cambia a logging.DEBUG si quieres ver aún más detalle
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.StreamHandler(sys.stdout)
    ],
    force=True # Forzamos la configuración incluso si otra librería la cambió
)

logging.info("✓ Sistema de logs configurado para Notebook")
# Out:
# 2026-01-10 05:55:45,549 - INFO - ✓ Sistema de logs configurado para Notebook

# %%
# Importar librerías necesarias
import sys
import json
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')

# Configurar estilo de gráficos
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# Importar módulos del proyecto
import config
from agents.transcription_agent import TranscriptionAgent
from agents.greeting_agent import GreetingAgent, QualityAgent
from agents.audio_processor import AudioProcessor

print("✓ Librerías importadas correctamente")
print(f"✓ Directorio de audios: {config.AUDIO_DIR}")
print(f"✓ Directorio de salida: {config.OUTPUT_DIR}")
# Out:
# ✓ Librerías importadas correctamente
# ✓ Directorio de audios: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\data\audios\MOVIL
# ✓ Directorio de salida: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output

# %% [markdown]
# ## 2. Agente de Transcripción
#
# Este agente:
# - Elimina silencios y tonos de espera
# - Transcribe audios a texto usando Whisper
# - Identifica participantes (speaker diarization)
# - Genera métricas de calidad

# %%
# Verificar archivos de audio disponibles
audio_extensions = ['.wav', '.mp3', '.m4a', '.flac', '.ogg']
audio_files = []
for ext in audio_extensions:
    audio_files.extend(config.AUDIO_DIR.glob(f"*{ext}"))

print(f"Archivos de audio encontrados: {len(audio_files)}")
for i, audio_file in enumerate(audio_files, 1):
    print(f"  {i}. {audio_file.name}")

if not audio_files:
    print("\n ADVERTENCIA: No se encontraron archivos de audio.")
    print(f"   Por favor, coloca archivos de audio en: {config.AUDIO_DIR}")
# Out:
# Archivos de audio encontrados: 50
#   1. 9155033267980001731 999799232 70942859 MASIVO_MOVIL ABAI 0906 _1.wav
#   2. 9155033327270001731 999799232 75316202 MASIVO_MOVIL ABAI 0906.wav
#   3. 9155034794510001731 945206356 09337147 MASIVO_MOVIL GSS 0906 _1.wav
#   4. 9155036654930001731 945206356 72467112 MASIVO_MOVIL KONECTA 0906.wav
#   5. 9155041036900001731 964061323 72396494 MASIVO_MOVIL ABAI 1006 _1.wav
#   6. 9155041370430001731 964061323 48576957 MASIVO_MOVIL ABAI 1006.wav
#   7. 9155042319270001731 998811016 74812275 MASIVO_MOVIL KONECTA 1006 _1.wav
#   8. 9155042371100001731 998811016 41398045 MASIVO_MOVIL KONECTA 1006.wav
#   9. 9155042433790001731 945668019 43191453 MASIVO_MOVIL KONECTA 1006 _1.wav
#   10. 9155042582490001731 945668019 70088919 MASIVO_MOVIL GSS 1006.wav
#   11. 9155050433020001731 924042582 77178070 MASIVO_MOVIL KONECTA 1106 _1.wav
#   12. 9155050514900001731 924042582 77038601 MASIVO_MOVIL KONECTA 1106.wav
#   13. 9155050950490001731 985994278 46042916 MASIVO_MOVIL GSS 1106 _1.wav
#   14. 9155051402710001731 938979985 44138641 MASIVO_MOVIL GSS 1106 _1.wav
#   15. 9155051458280001731 938979985 76267018 MASIVO_MOVIL KONECTA 1106.wav
#   16. 9155051629270001731 985994278 43191453 MASIVO_MOVIL KONECTA1106.wav
print(f" Archivos de transcripción encontrados: {len(transcription_files)}")

if transcription_files:
    print(f"\n✓ Ya existen {len(transcription_files)} transcripciones.")
    print(f"  Puedes saltar la transcripción y pasar directamente al análisis de calidad.")
    print(f"\n  Para re-transcribir, ejecuta las siguientes celdas.")
else:
    print(f"\n No hay transcripciones. Debes ejecutar el agente de transcripción primero.")
# Out:
#  Archivos de transcripción encontrados: 0
#
#  No hay transcripciones. Debes ejecutar el agente de transcripción primero.

# %%
# Inicializar agente de transcripción
print("Inicializando agente de transcripción...")
transcription_agent = TranscriptionAgent(
    whisper_model_name=config.WHISPER_MODEL,
    use_gpu=True
)
print("✓ Agente de transcripción listo")
# Out:
# Inicializando agente de transcripción...
# 2026-01-10 05:56:34,399 - INFO - Cargando Whisper 'large-v3-turbo' en cuda...
# 2026-01-10 05:56:34,845 - INFO - HTTP Request: GET https://huggingface.co/api/models/mobiuslabsgmbh/faster-whisper-large-v3-turbo/revision/main "HTTP/1.1 307 Temporary Redirect"
# 2026-01-10 05:56:34,976 - INFO - HTTP Request: GET https://huggingface.co/api/models/dropbox-dash/faster-whisper-large-v3-turbo/revision/main "HTTP/1.1 200 OK"
# 2026-01-10 05:56:39,555 - INFO - HTTP Request: HEAD https://huggingface.co/pyannote/speaker-diarization-3.1/resolve/main/config.yaml "HTTP/1.1 200 OK"
# 2026-01-10 05:56:41,002 - DEBUG - Registered checkpoint save hook for _speechbrain_save
# 2026-01-10 05:56:41,003 - DEBUG - Registered checkpoint load hook for _speechbrain_load
# 2026-01-10 05:56:41,003 - DEBUG - Registered checkpoint save hook for save
# 2026-01-10 05:56:41,003 - DEBUG - Registered checkpoint load hook for load
# 2026-01-10 05:56:41,276 - INFO - Applied quirks (see `speechbrain.utils.quirks`): [disable_jit_profiling, allow_tf32]
# 2026-01-10 05:56:41,276 - INFO - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# 2026-01-10 05:56:41,277 - DEBUG - Registered checkpoint save hook for _save
# 2026-01-10 05:56:41,277 - DEBUG - Registered checkpoint load hook for _recover
# 2026-01-10 05:56:41,427 - INFO - HTTP Request: HEAD https://huggingface.co/pyannote/segmentation-3.0/resolve/main/pytorch_model.bin "HTTP/1.1 302 Found"
# 2026-01-10 05:56:41,696 - INFO - HTTP Request: HEAD https://huggingface.co/pyannote/speaker-diarization-community-1/resolve/main/plda/xvec_transform.npz "HTTP/1.1 302 Found"
# 2026-01-10 05:56:41,832 - INFO - HTTP Request: HEAD https://huggingface.co/pyannote/speaker-diarization-community-1/resolve/main/plda/plda.npz "HTTP/1.1 302 Found"
# 2026-01-10 05:56:42,021 - INFO - HTTP Request: HEAD https://huggingface.co/pyannote/wespeaker-voxceleb-resnet34-LM/resolve/main/pytorch_model.bin "HTTP/1.1 302 Found"
# 2026-01-10 05:56:42,148 - ERROR - Error cargando diarización: 'str' object has no attribute 'type'
# 2026-01-10 05:56:42 | INFO     | DF | Running on torch 2.2.0+cu118
# 2026-01-10 05:56:42 | INFO     | DF | Running on host albertferz
# 2026-01-10 05:56:42 | INFO     | DF | Loading model settings of DeepFilterNet3
# 2026-01-10 05:56:42 | INFO     | DF | Using DeepFilterNet3 model at C:\Users\jfern\AppData\Local\DeepFilterNet\DeepFilterNet\Cache\DeepFilterNet3
# 2026-01-10 05:56:42 | INFO     | DF | Initializing model `deepfilternet3`
# 2026-01-10 05:56:42 | INFO     | DF | Found checkpoint C:\Users\jfern\AppData\Local\DeepFilterNet\DeepFilterNet\Cache\DeepFilterNet3\checkpoints\model_120.ckpt.best with epoch 120
# 2026-01-10 05:56:42 | INFO     | DF | Running on device cuda:0
# 2026-01-10 05:56:42 | INFO     | DF | Model loaded
# 2026-01-10 05:56:42,444 - INFO - DeepFilterNet inicializado correctamente en: cuda
# ✓ Agente de transcripción listo

# %% [markdown]
# ### 3.1 Procesar Audios
#
# Tienes dos opciones para procesar los audios:
# 1. **Opción A (Solo Transcripción)**: Mucho más rápida, ideal si solo necesitas el texto.
# 2. **Opción B (Solo Diarización)**: Añade la identificación de quién habla a los resultados de la Opción A. Es más lenta y requiere GPU.

# %%
# OPCIÓN A: Solo Transcripción (Rápido)
print("Iniciando SOLO TRANSCRIPCIÓN...\n")
transcription_results = transcription_agent.process_directory(
    audio_dir=str(config.AUDIO_DIR),
    output_dir=str(config.TRANSCRIPTION_DIR),
    preprocess=True,
    diarize=False  #Desactivamos la diarización para mayor velocidad
)

print(f"\n Transcripciones completadas: {len(transcription_results)}")
# Out:
# Iniciando SOLO TRANSCRIPCIÓN...
#
# Encontrados 50 archivos de audio
#
# ============================================================
# Procesando 1/50: 9155033267980001731 999799232 70942859 MASIVO_MOVIL ABAI 0906 _1.wav
# ============================================================
# 2026-01-10 05:56:45,728 - INFO - Preprocesando audio...
# Audio cargado exitosamente: 9155033267980001731 999799232 70942859 MASIVO_MOVIL ABAI 0906 _1.wav (422.9s, 8000Hz)
# 2026-01-10 05:56:46,383 - INFO - Aplicando filtro paso banda...
# 2026-01-10 05:56:50,716 - INFO - Eliminando tonos de espera...
# 2026-01-10 05:56:53,074 - INFO - Eliminando silencios...
# 2026-01-10 05:56:56,167 - INFO - Exportando para Whisper...
# 2026-01-10 05:56:56,200 - INFO - Audio exportado exitosamente con pydub: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155033267980001731 999799232 70942859 MASIVO_MOVIL ABAI 0906 _1.wav
# 2026-01-10 05:56:56,201 - INFO - Iniciando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155033267980001731 999799232 70942859 MASIVO_MOVIL ABAI 0906 _1.wav
# Audio cargado exitosamente: temp_9155033267980001731 999799232 70942859 MASIVO_MOVIL ABAI 0906 _1.wav (358.8s, 16000Hz)
# 2026-01-10 05:56:56,224 - INFO - Processing audio with duration 05:58.843
# 2026-01-10 05:56:56,910 - INFO - VAD filter removed 00:00.955 of audio
# 2026-01-10 05:57:04,204 - INFO - Transcripción completada para {'language': 'es', 'duration': 358.843, 'segments': [{'text': 'Hola, buen día. Bienvenido a Movistar. Le saludo a Raúl Paso, asesor con quien tengo el gusto de comunicarme.', 'start': 0.21, 'end': 5.71, 'no_speech_prob': 0.0, 'avg_logprob': -0.31926305458616855, 'compression_ratio': 1.5053003533568905}, {'text': 'Sí, está bien ahí, sí.', 'start': 5.71, 'end': 7.41, 'no_speech_prob': 0.0, 'avg_logprob': -0.31926305458616855, 'compression_ratio': 1.5053003533568905}, {'text': 'Ok, y me estimabas el mismo número por el cual te comunicas por el que desea realizar tu consulta?', 'start': 7.41, 'end': 11.71, 'no_speech_prob': 0.0, 'avg_logprob': -0.31926305458616855, 'compression_ratio': 1.5053003533568905}, {'text': 'Sí.', 'start': 11.71, 'end': 12.71, 'no_speech_prob': 0.0, 'avg_logprob': -0.31926305458616855, 'compression_ratio': 1.5053003533568905}, {'text': 'Ok, cuéntame, ¿cuál es el motivo de tu consulta en qué puedo ayudarte en este momento?', 'start': 12.71, 'end': 16.71, 'no_speech_prob': 0.0, 'avg_logprob': -0.31926305458616855, 'compression_
9155033327270001731 999799232 75316202 MASIVO_MOVIL ABAI 0906.wav
# ============================================================
# 2026-01-10 05:57:04,207 - INFO - Preprocesando audio...
# Audio cargado exitosamente: 9155033327270001731 999799232 75316202 MASIVO_MOVIL ABAI 0906.wav (250.9s, 8000Hz)
# 2026-01-10 05:57:04,322 - INFO - Aplicando filtro paso banda...
# 2026-01-10 05:57:06,659 - INFO - Eliminando tonos de espera...
# 2026-01-10 05:57:06,802 - INFO - Eliminando silencios...
# 2026-01-10 05:57:08,726 - INFO - Exportando para Whisper...
# 2026-01-10 05:57:08,749 - INFO - Audio exportado exitosamente con pydub: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155033327270001731 999799232 75316202 MASIVO_MOVIL ABAI 0906.wav
# 2026-01-10 05:57:08,750 - INFO - Iniciando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155033327270001731 999799232 75316202 MASIVO_MOVIL ABAI 0906.wav
# Audio cargado exitosamente: temp_9155033327270001731 999799232 75316202 MASIVO_MOVIL ABAI 0906.wav (229.5s, 16000Hz)
# 2026-01-10 05:57:08,767 - INFO - Processing audio with duration 03:49.544
# 2026-01-10 05:57:09,113 - INFO - VAD filter removed 00:00.400 of audio
# 2026-01-10 05:57:12,800 - INFO - Transcripción completada para {'language': 'es', 'duration': 229.544, 'segments': [{'text': 'Hola, muy buenos días. Bienvenida a Movistar, le saludo a Brenda Mejía. Tu número de consulta es el noventa y nueve, noventa y siete, noventa y nueve, veintitrés dosis, ¿correcto? Sí. Perfecto. Coméntame con quién tengo el gusto o cuál sería motivo en tu consulta. Yo estaba ganando mi consulta, que me dicen que no es pago. Ya. Ya. Y yo, eh, voy a entrar un número para ver, y dígame lo que me hizo, este, va a ir a la parte, y yo descubrimos', 'start': 0.21, 'end': 30.27, 'no_speech_prob': 0.0, 'avg_logprob': -0.42919580753032976, 'compression_ratio': 1.5689655172413792}, {'text': 'Y me han enviado a un WhatsApp dándome la dena. Pero ¿qué es usted? Yo he tratado hace una semana.', 'start': 30.27, 'end': 37.67, 'no_speech_prob': 0.0, 'avg_logprob': -0.34872786766659897, 'compression_ratio': 1.4834710743801653}, {'text': 'Ya.', 'start': 38.01, 'end': 38.41, 'no_speech_prob': 0.0, 'avg_logprob': -0.34872786766659897, 'compression_ratio': 1.4834710743801653}, {'text': 'Sí, sin embargo, me cortan. Me han cortado y lo peor, me han dejado sin celular. O sea, me han cortado las lupas de celulares.', 'start': 38.75, 'end': 48.75, 'no_speech_prob': 0.0, 'avg_logprob': -0.34872786766659897, 'compression_ratio': 1.4834710743801653}, {'text': 'Estoy acá con los que ustedes tendrían en el cliente o llamada 104, pero otras doctores no tengo que hacer, no puedo hacer.', 'start': 48.93, 'end': 57.83, 'no_speech_prob': 0.0, 'avg_logprob': -0.34872786766659897, 'compression_ratio': 1.4834710743801653}, {'text': 'Y esto es la segunda, lo que sé, no entiendo cómo en la parte de ACB, las deudas, si no envían los pagos.', 'start': 57.83, 'end': 68.37, 'no_speech_prob': 0.0, 'avg_logprob': -0.3950892732966514, 'compression_ratio': 1.450777202072539}, {'text': 'Ahora usted me va a decir el banco, ese es el punto de sentida, porque yo he pagado siempre con el banco de crédito y nunca he tenido problemas.', 'start': 68.87, 'end': 78.01, 'no_speech_prob': 0.0, 'avg_logprob': -0.3950892732966514, 'compression_ratio': 1.450777202072539}, {'text': 'Ya claro, en este caso...', 'start': 78.01, 'end': 80.25, 'no_speech_prob': 0.0, 'avg_logprob': -0.3950892732966514, 'compression_ratio': 1.450777202072539}, {'text': 'Claro, en este caso normalmente estoy verificando que hay un recibo que figura que no haya cancelado el día 5 de junio del 2025, entonces si tú me indicas que has cancelado hace una semana debido a que en este caso ya es un pago no procesado.', 'start': 80.25, 'end': 109.49, 'no_speech_prob': 0.0, 'avg_logprob': -0.14742943932933192, 'compression_ratio': 1.4698795180722892}, {'text': 'Nosotros para poder generar el desbloqueo del equipo y lo que es su línea, teníamos que en desarrollo lo que serían los solicitos directamente al área de posturaciones para que lo pueda actualizar.', 'start': 110.25, 'end': 120.21, 'no_speech_prob': 0.0, 'avg_logprob': -0.19186827251988073, 'compression_ratio': 1.5324675324675325}, {'text': 'En todo caso, ¿tú cuentas con lo que es el voucher o la captura en estos momentos para que me pueda validar la fecha, hora y el número de operación?', 'start': 120.69, 'end': 128.09, 'no_speech_prob': 0.0, 'avg_logprob': -0.19186827251988073, 'compression_ratio': 1.5324675324675325}, {'text': 'Mire, como le digo, ahorita no puedo entrar a mi aparato de celular. No puedo hacer nada en el caso de lo que usted me está pidiendo y no puedo hacer nada. No puedo ni sentir lo que usted me está pidiendo indicando.', 'start': 128.09, 'end': 144.75, 'no_speech_prob': 0.0, 'avg_logprob': -0.2676005623806482, 'compression_ratio': 1.72}, {'text': 'Claro, en todo caso nos podríamos ayudarle directamente si no nos valida esos datos para poderlo gestionarlo en este momento.', 'start': 145.19, 'end': 153.49, 'no_speech_prob': 0.0, 'avg_logprob': -0.2676005623806482, 'compression_ratio': 1.72}, {'text': 'No, no. Desgraciadament ...
# 2026-01-10 05:57:12,801 - INFO - Diarización desactivada por el usuario.
# 2026-01-10 05:57:12,801 - INFO - Combinando transcripción con speakers...
# Guardando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155033327270001731 999799232 75316202 MASIVO_MOVIL ABAI 0906_transcription.json
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155033327270001731 999799232 75316202 MASIVO_MOVIL ABAI 0906_transcription.json
# Completado: 9155033327270001731 999799232 75316202 MASIVO_MOVIL ABAI 0906.wav
#   - Calidad: 91.0%
#   - Speakers: 1
#   - Duracion: 250.9s
#
# ============================================================
# Procesando 3/50: 9155034794510001731 945206356 09337147 MASIVO_MOVIL GSS 0906 _1.wav
# ============================================================
# 2026-01-10 05:57:12,803 - INFO - Preprocesando audio...
# Audio cargado exitosamente: 9155034794510001731 945206356 09337147 MASIVO_MOVIL GSS 0906 _1.wav (457.3s, 8000Hz)
# 2026-01-10 05:57:13,116 - INFO - Aplicando filtro paso banda...
# 2026-01-10 05:57:17,326 - INFO - Eliminando tonos de espera...
# 2026-01-10 05:57:17,561 - INFO - Eliminando silencios...
# 2026-01-10 05:57:21,002 - INFO - Exportando para Whisper...
# 2026-01-10 05:57:21,024 - INFO - Audio exportado exitosamente con pydub: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155034794510001731 945206356 09337147 MASIVO_MOVIL GSS 0906 _1.wav
# 2026-01-10 05:57:21,025 - INFO - Iniciando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155034794510001731 945206356 09337147 MASIVO_MOVIL GSS 0906 _1.wav
# Audio cargado exitosamente: temp_9155034794510001731 945206356 09337147 MASIVO_MOVIL GSS 0906 _1.wav (219.6s, 16000Hz)
# 2026-01-10 05:57:21,042 - INFO - Processing audio with duration 03:39.629
# 2026-01-10 05:57:21,392 - INFO - VAD filter removed 00:09.392 of audio
# 2026-01-10 05:57:25,879 - INFO - Transcripción completada para {'language': 'es', 'duration': 219.629, 'segments': [{'text': 'Gracias por la espera, bienvenido a Movistar. Te saluda Jorge Grimaldos, asesor especializado. Con mi gusto comunicarme.', 'start': 0.21, 'end': 6.41, 'no_speech_prob': 0.0, 'avg_logprob': -0.3172123124675145, 'compression_ratio': 1.5017421602787457}, {'text': 'Hola, buen día. Sí, quería llamar para ver por qué todavía no se ha confirmado una deuda pendiente con mi adictivo número.', 'start': 6.41, 'end': 19.61, 'no_speech_prob': 0.0, 'avg_logprob': -0.3172123124675145, 'compression_ratio': 1.5017421602787457}, {'text': 'A ver, vamos a ver ya. Vamos a ver un segundito. Vale, ahora sí me estimaba. ¿Cuál es el motivo de la consulta? El número que... ¿Por cuál quiere consultar? ¿Qué número es?', 'start': 19.61, 'end': 28.67, 'no_speech_prob': 0.0, 'avg_logprob': -0.3172123124675145,
- INFO - Diarización desactivada por el usuario.
# 2026-01-10 05:57:25,880 - INFO - Combinando transcripción con speakers...
# Guardando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155034794510001731 945206356 09337147 MASIVO_MOVIL GSS 0906 _1_transcription.json
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155034794510001731 945206356 09337147 MASIVO_MOVIL GSS 0906 _1_transcription.json
# Completado: 9155034794510001731 945206356 09337147 MASIVO_MOVIL GSS 0906 _1.wav
#   - Calidad: 88.2%
#   - Speakers: 1
#   - Duracion: 457.3s
#
# ============================================================
# Procesando 4/50: 9155036654930001731 945206356 72467112 MASIVO_MOVIL KONECTA 0906.wav
# ============================================================
# 2026-01-10 05:57:25,882 - INFO - Preprocesando audio...
# Audio cargado exitosamente: 9155036654930001731 945206356 72467112 MASIVO_MOVIL KONECTA 0906.wav (558.5s, 8000Hz)
# 2026-01-10 05:57:26,248 - INFO - Aplicando filtro paso banda...
# 2026-01-10 05:57:33,597 - INFO - Eliminando tonos de espera...
# 2026-01-10 05:57:33,907 - INFO - Eliminando silencios...
# 2026-01-10 05:57:38,184 - INFO - Exportando para Whisper...
# 2026-01-10 05:57:38,220 - INFO - Audio exportado exitosamente con pydub: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155036654930001731 945206356 72467112 MASIVO_MOVIL KONECTA 0906.wav
# 2026-01-10 05:57:38,220 - INFO - Iniciando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155036654930001731 945206356 72467112 MASIVO_MOVIL KONECTA 0906.wav
# Audio cargado exitosamente: temp_9155036654930001731 945206356 72467112 MASIVO_MOVIL KONECTA 0906.wav (371.3s, 16000Hz)
# 2026-01-10 05:57:38,246 - INFO - Processing audio with duration 06:11.298
# 2026-01-10 05:57:38,852 - INFO - VAD filter removed 01:57.890 of audio
# 2026-01-10 05:57:50,166 - INFO - Transcripción completada para {'language': 'es', 'duration': 371.298, 'segments': [{'text': 'Hola, muy buenas tardes. Bienvenido a Movistar. Te saludo, Dayanel Apolo. Tu número en consulta es el 945-2063-56, ¿es correcto? Eh, es de otro número. Ok. Ok, estimado, no se preocupe. A ver, permítame un momento, por favor. Ok, bríndemelo, por favor. Noventa y siete... No, perdón. Noventa y cuatro siete cuatro dos dos seis cinco nueve. Listo,', 'start': 0.62, 'end': 31.01, 'no_speech_prob': 0.0, 'avg_logprob': -0.22470868505158667, 'compression_ratio': 1.436734693877551}, {'text': '422-659, ¿correcto?', 'start': 31.01, 'end': 34.39, 'no_speech_prob': 0.0, 'avg_logprob': -0.45470184251802775, 'compression_ratio': 1.3333333333333333}, {'text': 'Sí.', 'start': 35.24, 'end': 35.52, 'no_speech_prob': 0.0, 'avg_logprob': -0.45470184251802775, 'compression_ratio': 1.3333333333333333}, {'text': 'Ok.', 'start': 36.2, 'end': 36.58, 'no_speech_prob': 0.0, 'avg_logprob': -0.45470184251802775, 'compression_ratio': 1.3333333333333333}, {'text': 'Ok, estimado, con quien tengo el gusto en esta oportunidad.', 'start': 37.1, 'end': 40.1, 'no_speech_prob': 0.0, 'avg_logprob': -0.45470184251802775, 'compression_ratio': 1.3333333333333333}, {'text': 'José.', 'start': 40.76, 'end': 41.36, 'no_speech_prob': 0.0, 'avg_logprob': -0.45470184251802775, 'compression_ratio': 1.3333333333333333}, {'text': 'Señor José, coméntenme en qué puedo ayudarle.', 'start': 42.17, 'end': 45.25, 'no_speech_prob': 0.0, 'avg_logprob': -0.45470184251802775, 'compression_ratio': 1.3333333333333333}, {'text': 'Llamar a hacer, perdón, bueno, ya llevo 24 horas llamando para que me recomienden la línea,', 'start': 47.75, 'end': 53.65, 'no_speech_prob': 0.0, 'avg_logprob': -0.45470184251802775, 'compression_ratio': 1.3333333333333333}, {'text': 'que haya cortado por deuda.', 'start': 53.81, 'end': 55.79, 'no_speech_prob': 0.0, 'avg_logprob': -0.45470184251802775, 'compression_ratio': 1.3333333333333333}, {'text': 'Ya.', 'start': 56.61, 'end': 56.95, 'no_speech_prob': 0.0, 'avg_logprob': -0.45470184251802775, 'compression_ratio': 1.3333333333333333}, {'text': 'Y estaría dando las...', 'start': 57.47, 'end': 58.71, 'no_speech_prob': 0.0, 'avg_logprob': -0.45470184251802775, 'compression_ratio': 1.3333333333333333}, {'text': 'Ok. ¿El número del que le deben de reconectar la línea es el noventa y cuatro setenta y cuatro veintidós seis cinco nueve?', 'start': 58.71, 'end': 65.47, 'no_speech_prob': 0.0, 'avg_logprob': -0.5380154835809138, 'compression_ratio': 1.349726775956284}, {'text': 'Sí.', 'start': 65.91, 'end': 66.15, 'no_speech_prob': 0.0, 'avg_logprob': -0.5380154835809138, 'compression_ratio': 1.349726775956284}, {'text': 'Ya.', 'start': 66.63, 'end': 67.27, 'no_speech_prob': 0.0, 'avg_logprob': -0.5380154835809138, 'compression_ratio': 1.349726775956284}, {'text': '¿Está su nombre?', 'start': 69.01, 'end': 70.85, 'no_speech_prob': 0.0, 'avg_logprob': -0.5380154835809138, 'compression_ratio': 1.349726775956284}, {'text': 'No, es titular, es clor, asesor, de González.', 'start': 72.51, 'end': 76.09, 'no_speech_prob': 0.0, 'avg_logprob': -0.5380154835809138, 'compression_ratio': 1.349726775956284}, {'text': 'Ok.', 'start': 76.41, 'end': 76.89, 'no_speech_prob': 0.0, 'avg_logprob': -0.5380154835809138, 'compression_ratio': 1.349726775956284}, {'text': 'Ok.', 'start': 76.89, 'end': 77.01, 'no_speech_prob': 0.0, 'avg_logprob': -0.5380154835809138, 'compression_ratio': 1.349726775956284}, {'text': 'A ver, un momento, línea, por favor.', 'start': 85.07, 'end': 91.03, 'no_speech_prob': 0.0, 'avg_logprob': -0.5380154835809138, 'compression_ratio': 1.349726775956284}, {'text': 'Señor José, ¿sí? No me vaya a cortar.', 'start': 91.03, 'end': 93.35, 'no_speech_prob': 0.0, 'avg_logprob': -0.16601562034338713, 'compression_ratio': 0.82}, {'text': 'Ya, ok, estimado, muchas gracias por su gentil espera.', 'start': 141.58, 'end': 256.75, 'no_speech_prob': 0.0, 'avg_l ...
# 2026-01-10 05:57:50,166 - INFO - Diarización desactivada por el usuario.
# 2026-01-10 05:57:50,167 - INFO - Combinando transcripción con speakers...
# Guardando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155036654930001731 945206356 72467112 MASIVO_MOVIL KONECTA 0906_transcription.json
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155036654930001731 945206356 72467112 MASIVO_MOVIL KONECTA 0906_transcription.json
# Completado: 9155036654930001731 945206356 72467112 MASIVO_MOVIL KONECTA 0906.wav
#   - Calidad: 87.0%
#   - Speakers: 1
#   - Duracion: 558.5s
#
# ============================================================
# Procesando 5/50: 9155041036900001731 964061323 72396494 MASIVO_MOVIL ABAI 1006 _1.wav
# ============================================================
# 2026-01-10 05:57:50,169 - INFO - Preprocesando audio...
# Audio cargado exitosamente: 9155041036900001731 964061323 72396494 MASIVO_MOVIL ABAI 1006 _1.wav (453.0s, 8000Hz)
# 2026-01-10 05:57:50,348 - INFO - Aplicando filtro paso banda...
# 2026-01-10 05:57:54,731 - INFO - Eliminando tonos de espera...
# 2026-01-10 05:57:54,987 - INFO - Eliminando silencios...
# 2026-01-10 05:57:58,496 - INFO - Exportando para Whisper...
# 2026-01-10 05:57:58,526 - INFO - Audio exportado exitosamente con pydub: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155041036900001731 964061323 72396494 MASIVO_MOVIL ABAI 1006 _1.wav
# 2026-01-10 05:57:58,527 - INFO - Iniciando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155041036900001731 964061323 72396494 MASIVO_MOVIL ABAI 1006 _1.wav
# Audio cargado exitosamente: temp_9155041036900001731 964061323 72396494 MASIVO_MOVIL ABAI 1006 _1.wav (296.8s, 16000Hz)
# 2026-01-10 05:57:58,548 - INFO - Processing audio with duration 04:56.785
# 2026-01-10 05:57:59,019 - INFO - VAD filter removed 00:03.825 of audio
# 2026-01-10 05:58:13,642 - INFO - Transcripción completada para {'language': 'es', 'duration': 296.785, 'segments': [{'text': 'Hola, buen día. Mi nombre es Richard. Saluda a todos los muros de teléfono del día de hoy. Indíqueme el número en consulta. ¿Es el 9640-6182-3? Sí. Un momento. ¿Me pones la consulta de ese servicio? Eh, mi consulta es, eh, me llamaron hace tres días atrás, eh, me ofrecieron una tarifa para poder pagar, ¿no?, para estar con el FOSPA. Y bueno, me dijeron que me evaluaron y, bueno, califiqué y me dijeron que iban a activar', 'start': 0.3, 'end': 30.3, 'no_speech_prob': 0.0, 'avg_logprob': -0.40556065299931693, 'compression_ratio': 1.4795918367346939}, {'text': 'Dentro de una hora, ¿no? Y no sé cuál es el motivo por qué aún no lo activan. O era una llamada falsa, quisiera saber que me informara.', 'start': 30.3, 'end': 41.04, 'no_speech_prob': 0.0, 'avg_logprob': -0.2523521364376109, 'compression_ratio': 1.6210526315789473}, {'text': 'No puede navegar.', 'start': 41.82, 'end': 42.78, 'no_speech_prob': 0.0, 'avg_logprob': -0.2523521364376109, 'compression_ratio': 1.6210526315789473}, {'text': 'O sea, no tanto navegar, sino quisiera saber el motivo porque dentro de una hora ya debería llegar, ¿no?', 'start': 44.16, 'end': 52.28, 'no_speech_prob': 0.0, 'avg_logprob': -0.2523521364376109, 'compression_ratio': 1.6210526315789473}, {'text': 'Pero no puede navegar el servicio, ¿qué?', 'start': 52.88, 'end': 54.64, 'no_speech_prob': 0.0, 'avg_logprob': -0.2523521364376109, 'compression_ratio': 1.6210526315789473}, {'text': 'Eh, no, quisiera saber, ¿no?', 'start': 54.64, 'end': 56.7, 'no_speech_prob': 0.0, 'avg_logprob': -0.3983433787004057, 'compression_ratio': 1.6777408637873754}, {'text': 'Pero no puede saber.', 'start': 56.78, 'end': 57.7, 'no_speech_prob': 0.0, 'avg_logprob': -0.3983433787004057, 'compression_ratio': 1.6777408637873754}, {'text': '¿Pero cuál es el inconveniente?', 'start': 57.94, 'end': 58.86, 'no_speech_prob': 0.0, 'avg_logprob': -0.3983433787004057, 'compression_ratio': 1.6777408637873754}, {'text': '¿No puede navegar?', 'start': 58.92, 'end': 59.68, 'no_speech_prob': 0.0, 'avg_logprob': -0.3983433787004057, 'compression_ratio': 1.6777408637873754}, {'text': '¿No puede generar llamadas?', 'start': 59.78, 'end': 60.8, 'no_speech_prob': 0.0, 'avg_logprob': -0.3983433787004057, 'compression_ratio': 1.6777408637873754}, {'text': 'No, yo tenía una recarga normal.', 'start': 61.26, 'end': 62.82, 'no_speech_prob': 0.0, 'avg_logprob': -0.3983433787004057, 'compression_ratio': 1.6777408637873754}, {'text': 'Porque hago una recarga normal y no sé, no llega pues, ¿no?, ningún mensaje o ningún comunicado que ya está activado, pues, ¿no?, el paspado que me hicieron.', 'start': 63.16, 'end': 74.32, 'no_speech_prob': 0.0, 'avg_logprob': -0.3983433787004057, 'compression_ratio': 1.6777408637873754}, {'text': 'Comenta, ¿cuál es su nombre?', 'start': 75.1, 'end': 76.14, 'no_speech_prob': 0.0, 'avg_logprob': -0.3983433787004057, 'compression_ratio': 1.6777408637873754}, {'text': 'Es mi Sara.', 'start': 77.11, 'end': 77.87, 'no_speech_prob': 0.0, 'avg_logprob': -0.3983433787004057, 'compression_ratio': 1.6777408637873754}, {'text': 'Comunicarme contigo Jesús.', 'start': 79.12, 'end': 80.32, 'no_speech_prob': 0.0, 'avg_logprob': -0.3983433787004057, 'compression_ratio': 1.6777408637873754}, {'text': 'En caso de cuarentena la comunicación te puedo volver a llamar al número del cual te comunicas.', 'start': 80.52, 'end': 84.28, 'no_speech_prob': 0.0, 'avg_logprob': -0.3983433787004057, 'compression_ratio': 1.6777408637873754}, {'text': 'Sí.', 'start': 84.8, 'end': 85.0, 'no_speech_prob': 0.0, 'avg_logprob': -0.3983433787004057, 'compression_ratio': 1.6777408637873754}, {'text': 'Sería muy amable.', 'start': 85.16, 'end': 86.98, 'no_speech_prob': 0.0, 'avg_logprob': -0.3531503919663468, 'compression_ratio': 1.6333333333333333}, {'text': 'Ok, me perdí el servicio de activo caballero como servicio postpago.', 'start': ...
# 2026-01-10 05:58:13,643 - INFO - Diarización desactivada por el usuario.
# 2026-01-10 05:58:13,643 - INFO - Combinando transcripción con speakers...
# Guardando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155041036900001731 964061323 72396494 MASIVO_MOVIL ABAI 1006 _1_transcription.json
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155041036900001731 964061323 72396494 MASIVO_MOVIL ABAI 1006 _1_transcription.json
# Completado: 9155041036900001731 964061323 72396494 MASIVO_MOVIL ABAI 1006 _1.wav
#   - Calidad: 86.5%
#   - Speakers: 1
#   - Duracion: 453.0s
#
# ============================================================
# Procesando 6/50: 9155041370430001731 964061323 48576957 MASIVO_MOVIL ABAI 1006.wav
# ============================================================
# 2026-01-10 05:58:13,646 - INFO - Preprocesando audio...
# Audio cargado exitosamente: 9155041370430001731 964061323 48576957 MASIVO_MOVIL ABAI 1006.wav (824.4s, 8000Hz)
# 2026-01-10 05:58:13,883 - INFO - Aplicando filtro paso banda...
# 2026-01-10 05:58:53,263 - INFO - Eliminando tonos de espera...
# 2026-01-10 05:58:53,705 - INFO - Eliminando silencios...
# 2026-01-10 05:58:59,976 - INFO - Exportando para Whisper...
# 2026-01-10 05:59:00,095 - INFO - Audio exportado exitosamente con pydub: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155041370430001731 964061323 48576957 MASIVO_MOVIL ABAI 1006.wav
# 2026-01-10 05:59:00,096 - INFO - Iniciando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155041370430001731 964061323 48576957 MASIVO_MOVIL ABAI 1006.wav
# Audio cargado exitosamente: temp_9155041370430001731 964061323 48576957 MASIVO_MOVIL ABAI 1006.wav (550.9s, 16000Hz)
# 2026-01-10 05:59:00,131 - INFO - Processing audio with duration 09:10.913
# 2026-01-10 05:59:01,052 - INFO - VAD filter removed 00:10.369 of audio
# 2026-01-10 05:59:30,408 - INFO - Transcripción completada para {'language': 'es', 'duration': 550.913, 'segments': [{'text': 'Buenos días, bienvenido a Movistar. Te saluda Sheila Cabrera de Movistar. El número de consulta es el número noventa y seis cuarenta y seis sesenta y uno trescientos veintitrés, ¿correcto? Sí, correcto. De acuerdo, muchas gracias. Por favor, en caso de corte la comunicación, ¿te puedo regresar la llamada de este número o prefiere lo que es la devolución de algún otro número de referencia? No, este número. De acuerdo, muchas gracias. Por favor, indícame tu consulta. Bueno, esta es la tercera vez que estoy llamando', 'start': 0.18, 'end': 30.21, 'no_speech_prob': 0.0, 'avg_logprob': -0.15079195062591605, 'compression_ratio': 1.7792642140468227}, {'text': 'No me dan solución, porque yo hace tres o cuatro días hice mi plan para todo estado. Y hasta el momento no me activan pues, pero hice la llamada anterior también y me dijeron que ya está activado, pero no puedo navegar, ¿no?', 'start': 30.21, 'end': 49.33, 'no_speech_prob': 0.0, 'avg_logprob': -0.2577285087236794, 'compression_ratio': 1.4891774891774892}, {'text': 'De acuerdo. Indícame en este lugar donde tú estás, desde qué lugar te estás comunicando.', 'start': 49.73, 'end': 56.49, 'no_speech_prob': 0.0, 'avg_logprob': -0.2577285087236794, 'compression_ratio': 1.4891774891774892}, {'text': 'Concepción, Junín.', 'start': 57.33, 'end': 58.51, 'no_speech_prob': 0.0, 'avg_logprob': -0.2577285087236794, 'compression_ratio': 1.4891774891774892}, {'text': 'Ah, ya de acuerdo. Ahorita estoy verificando todo lo que es relacionado a tu consulta en este aspecto. Permíteme un breve minuto. Estoy procediendo a lo que es la respectiva verificación, pero antes de ello, confírmame algo. En caso tú me indicaste que se vaya a cortar lo que es la comunicación, ¿se te puede regresar la llamada a este número o prefieres lo que es la devolución a algún otro número de referencia?', 'start': 58.51, 'end': 80.18, 'no_speech_prob': 0.0, 'avg_logprob': -0.13545867320029967, 'compression_ratio': 1.7252747252747254}, {'text': 'No tengo otro número, solamente este número.', 'start': 80.46, 'end': 82.76, 'no_speech_prob': 0.0, 'avg_logprob': -0.13545867320029967, 'compression_ratio': 1.7252747252747254}, {'text': 'En este caso es este número, ¿de acuerdo? Y ahorita respectivamente estoy revisando tu línea. ¿Desde cuándo estás con este problema?', 'start': 82.76, 'end': 89.58, 'no_speech_prob': 0.0, 'avg_logprob': -0.1585286397797366, 'compression_ratio': 1.4823008849557522}, {'text': 'Bueno, me hicieron una llamada, una oferta el día jueves o viernes, la semana pasada, y me dijeron que estoy seleccionado, algo así, y me llamaron y me suponieron para hacer un plan de postpago.', 'start': 90.06, 'end': 107.77, 'no_speech_prob': 0.0, 'avg_logprob': -0.1585286397797366, 'compression_ratio': 1.4823008849557522}, {'text': 'Ya de acuerdo.', 'start': 107.77, 'end': 137.75, 'no_speech_prob': 0.0, 'avg_logprob': -0.34960936648505075, 'compression_ratio': 0.6363636363636364}, {'text': '¿Me han activado o no? Dijo, ¿no? En plan. Entonces me doy con la sorpresa que sí ya me habían activado el día 6, 3 y 7 y 5.', 'start': 137.77, 'end': 148.77, 'no_speech_prob': 0.0, 'avg_logprob': -0.26693801919953164, 'compression_ratio': 1.5372549019607844}, {'text': 'Pero hasta el momento yo no puedo navegar, entonces yo no voy a pagar por un plan o por un producto que no puedo escucharlo.', 'start': 149.65, 'end': 157.53, 'no_speech_prob': 0.0, 'avg_logprob': -0.26693801919953164, 'compression_ratio': 1.5372549019607844}, {'text': 'Y eso es el motivo de mi llamada que hago varios días.', 'start': 158.17, 'end': 160.87, 'no_speech_prob': 0.0, 'avg_logprob': -0.26693801919953164, 'compression_ratio': 1.5372549019607844}, {'text': 'Ah, ya de acuerdo, comprende. Es decir, tú no estás podiendo navegar, ¿verdad?', 'start': 161.25, 'end': 164.31, 'no_speech_prob': 0.0, 'avg_logprob': -0.26693801919953164, 'compressi ...
# 2026-01-10 05:59:30,408 - INFO - Diarización desactivada por el usuario.
# 2026-01-10 05:59:30,409 - INFO - Combinando transcripción con speakers...
# Guardando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155041370430001731 964061323 48576957 MASIVO_MOVIL ABAI 1006_transcription.json
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155041370430001731 964061323 48576957 MASIVO_MOVIL ABAI 1006_transcription.json
# Completado: 9155041370430001731 964061323 48576957 MASIVO_MOVIL ABAI 1006.wav
#   - Calidad: 93.4%
#   - Speakers: 1
#   - Duracion: 824.4s
#
# ============================================================
# Procesando 7/50: 9155042319270001731 998811016 74812275 MASIVO_MOVIL KONECTA 1006 _1.wav
# ============================================================
# 2026-01-10 05:59:30,411 - INFO - Preprocesando audio...
# Audio cargado exitosamente: 9155042319270001731 998811016 74812275 MASIVO_MOVIL KONECTA 1006 _1.wav (162.6s, 8000Hz)
# 2026-01-10 05:59:30,527 - INFO - Aplicando filtro paso banda...
# 2026-01-10 05:59:32,102 - INFO - Eliminando tonos de espera...
# 2026-01-10 05:59:32,190 - INFO - Eliminando silencios...
# 2026-01-10 05:59:33,393 - INFO - Exportando para Whisper...
# 2026-01-10 05:59:33,407 - INFO - Audio exportado exitosamente con pydub: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155042319270001731 998811016 74812275 MASIVO_MOVIL KONECTA 1006 _1.wav
# 2026-01-10 05:59:33,407 - INFO - Iniciando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155042319270001731 998811016 74812275 MASIVO_MOVIL KONECTA 1006 _1.wav
# Audio cargado exitosamente: temp_9155042319270001731 998811016 74812275 MASIVO_MOVIL KONECTA 1006 _1.wav (146.1s, 16000Hz)
# 2026-01-10 05:59:33,421 - INFO - Processing audio with duration 02:26.137
# 2026-01-10 05:59:33,631 - INFO - VAD filter removed 00:00.761 of audio
# 2026-01-10 05:59:38,560 - INFO - Transcripción completada para {'language': 'es', 'duration': 146.137, 'segments': [{'text': 'Hola, muy buenos días. Bienvenido a Movistar. Les saluda a José Flores, un cliente muy listo.', 'start': 0.27, 'end': 4.27, 'no_speech_prob': 0.0, 'avg_logprob': -0.3274456438810929, 'compression_ratio': 1.4710743801652892}, {'text': 'Hola, buenos días. Se comunica con el titular del niño. Quería consultar para cambiar de plan.', 'start': 4.27, 'end': 11.27, 'no_speech_prob': 0.0, 'avg_logprob': -0.3274456438810929, 'compression_ratio': 1.4710743801652892}, {'text': '¿Quiere cambiar de plan? Correcto.', 'start': 11.27, 'end': 13.27, 'no_speech_prob': 0.0, 'avg_logprob': -0.3274456438810929, 'compression_ratio': 1.4710743801652892}, {'text': 'En este caso claramente el número de la consulta es el mismo, 988-811-016. Correcto.', 'start': 13.27, 'end': 20.27, 'no_speech_prob': 0.0, 'avg_logprob': -0.3274456438810929, 'compression_ratio': 1.4710743801652892}, {'text': 'Vamos a revisarlo. ¿Cuál es su nombre?', 'start': 21.27, 'end': 23.27, 'no_speech_prob': 0.0, 'avg_logprob': -0.3274456438810929, 'compression_ratio': 1.4710743801652892}, {'text': 'El nombre del que está el teléfono es de mi mamá, le estoy dando soporte. Le voy a dictar el nombre de mi mamá. ¿Qué dice su nombre? Aquí está la línea. Su nombre es Angelica Mamani Coyo.', 'start': 23.27, 'end': 37.69, 'no_speech_prob': 0.0, 'avg_logprob': -0.22745901309564465, 'compression_ratio': 1.5798319327731092}, {'text': 'Es la línea está el nombre de su mamá, me dice, ¿no?', 'start': 38.17, 'end': 40.25, 'no_speech_prob': 0.0, 'avg_logprob': -0.22745901309564465, 'compression_ratio': 1.5798319327731092}, {'text': 'Correcto, correcto.', 'start': 41.1, 'end': 41.94, 'no_speech_prob': 0.0, 'avg_logprob': -0.22745901309564465, 'compression_ratio': 1.5798319327731092}, {'text': '¿A qué plan desea cambiar?', 'start': 42.06, 'end': 43.22, 'no_speech_prob': 0.0, 'avg_logprob': -0.22745901309564465, 'compression_ratio': 1.5798319327731092}, {'text': 'Para dejar de pagar mensuales.', 'start': 43.68, 'end': 45.42, 'no_speech_prob': 0.0, 'avg_logprob': -0.22745901309564465, 'compression_ratio': 1.5798319327731092}, {'text': 'Ah, eso es migración a prepago.', 'start': 46.2, 'end': 47.5, 'no_speech_prob': 0.0, 'avg_logprob': -0.22745901309564465, 'compression_ratio': 1.5798319327731092}, {'text': 'Correcto.', 'start': 48.04, 'end': 48.52, 'no_speech_prob': 0.0, 'avg_logprob': -0.22745901309564465, 'compression_ratio': 1.5798319327731092}, {'text': 'Para generar la migración a prepago, tiene que generarlo después de haber cancelado su último recibo. Tiene un monto pendiente a pago, mi estimado.', 'start': 48.52, 'end': 55.23, 'no_speech_prob': 0.0, 'avg_logprob': -0.1624139913725197, 'compression_ratio': 1.5783132530120483}, {'text': 'Ah, entiendo. Después de cancelar, ¿qué debería hacer para cambiar, migrar a prepago?', 'start': 55.69, 'end': 65.59, 'no_speech_prob': 0.0, 'avg_logprob': -0.1624139913725197, 'compression_ratio': 1.5783132530120483}, {'text': 'Claro, mira, en este caso directamente el último día de pago es el día 17. La operación ya está emitida. Si la paga antes, no hay ningún problema.', 'start': 66.51, 'end': 76.37, 'no_speech_prob': 0.0, 'avg_logprob': -0.1624139913725197, 'compression_ratio': 1.5783132530120483}, {'text': 'Si le paga el mismo 17, ese mismo día se comunica indicándole a la operadora que desea emigrar a prepago. Así directamente lo van a derivar al área que corresponde ya sin deuda pendiente ni nada. Por eso es como muy importante primero pagar para que en el sistema figure sin deuda y nada. Y ahí va a proceder con ello. Así como le indica a la operadora si quiere emigrar a prepago, lo van a derivar al área encargada y así le estaríamos llegando.', 'start': 76.37, 'end': 98.59, 'no_speech_prob': 0.0, 'avg_logprob': -0.16766401258766228, 'compression_ratio': 1.7724137931034483}, {'text': 'Perfecto. Ya voy a realizar el pago en estos mo ...
# 2026-01-10 05:59:38,561 - INFO - Diarización desactivada por el usuario.
# 2026-01-10 05:59:38,562 - INFO - Combinando transcripción con speakers...
# Guardando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155042319270001731 998811016 74812275 MASIVO_MOVIL KONECTA 1006 _1_transcription.json
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155042319270001731 998811016 74812275 MASIVO_MOVIL KONECTA 1006 _1_transcription.json
# Completado: 9155042319270001731 998811016 74812275 MASIVO_MOVIL KONECTA 1006 _1.wav
#   - Calidad: 91.0%
#   - Speakers: 1
#   - Duracion: 162.6s
#
# ============================================================
# Procesando 8/50: 9155042371100001731 998811016 41398045 MASIVO_MOVIL KONECTA 1006.wav
# ============================================================
# 2026-01-10 05:59:38,564 - INFO - Preprocesando audio...
# Audio cargado exitosamente: 9155042371100001731 998811016 41398045 MASIVO_MOVIL KONECTA 1006.wav (263.5s, 8000Hz)
# 2026-01-10 05:59:38,684 - INFO - Aplicando filtro paso banda...
# 2026-01-10 05:59:41,158 - INFO - Eliminando tonos de espera...
# 2026-01-10 05:59:41,302 - INFO - Eliminando silencios...
# 2026-01-10 05:59:43,289 - INFO - Exportando para Whisper...
# 2026-01-10 05:59:43,307 - INFO - Audio exportado exitosamente con pydub: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155042371100001731 998811016 41398045 MASIVO_MOVIL KONECTA 1006.wav
# 2026-01-10 05:59:43,308 - INFO - Iniciando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155042371100001731 998811016 41398045 MASIVO_MOVIL KONECTA 1006.wav
# Audio cargado exitosamente: temp_9155042371100001731 998811016 41398045 MASIVO_MOVIL KONECTA 1006.wav (174.9s, 16000Hz)
# 2026-01-10 05:59:43,323 - INFO - Processing audio with duration 02:54.917
# 2026-01-10 05:59:43,581 - INFO - VAD filter removed 00:10.245 of audio
# 2026-01-10 05:59:50,121 - INFO - Transcripción completada para {'language': 'es', 'duration': 174.917, 'segments': [{'text': 'Hola, buenos días. Bienvenido a Movistar. Te saluda el evangelista. Te comunicas por el número en consulta. Correcto. 99 88 11 016. Correcto. En caso de corte la comunicación, le devuelvo la llamada al número al cual se está comunicando. Sí, está bien. Me comenta, por favor, el motivo de su llamado. Migración a prepago. Solicita la migración a prepago. ¿Por qué motivo solicita la migración? Disculpe. Factores económicos. Entiendo.', 'start': 0.72, 'end': 31.07, 'no_speech_prob': 0.0, 'avg_logprob': -0.18087499380111693, 'compression_ratio': 1.6195652173913044}, {'text': '¿Cuánto es el plan que realiza el pago?', 'start': 31.07, 'end': 32.65, 'no_speech_prob': 0.0, 'avg_logprob': -0.28207963335830555, 'compression_ratio': 1.4698795180722892}, {'text': 'Actualmente se está pagando 29,90.', 'start': 33.21, 'end': 35.37, 'no_speech_prob': 0.0, 'avg_logprob': -0.28207963335830555, 'compression_ratio': 1.4698795180722892}, {'text': 'En este caso me podría validar su nombre por favor, usted sea el titular del servicio.', 'start': 35.89, 'end': 40.11, 'no_speech_prob': 0.0, 'avg_logprob': -0.28207963335830555, 'compression_ratio': 1.4698795180722892}, {'text': 'No, es de mi mamá, yo le estoy dando soporte, le he dictado el nombre de mi mamá, Angélica Mamani Coyo con doble escribido.', 'start': 40.93, 'end': 50.42, 'no_speech_prob': 0.0, 'avg_logprob': -0.28207963335830555, 'compression_ratio': 1.4698795180722892}, {'text': 'Ok, un momento más en línea por favor, estoy validando la información.', 'start': 50.42, 'end': 59.92, 'no_speech_prob': 0.0, 'avg_logprob': -0.28207963335830555, 'compression_ratio': 1.4698795180722892}, {'text': 'Muy bien. Muchas gracias. Un momento más, por favor, no me voy a cortar. Gracias. En este caso, ¿me podría comunicar con su mamá? ¿Se encuentra con usted? Ya que el trámite en este caso lo tendría que realizar la señora. A ver, por favor.', 'start': 59.92, 'end': 79.74, 'no_speech_prob': 0.0, 'avg_logprob': -0.14855239145896015, 'compression_ratio': 1.3442622950819672}, {'text': 'Hola. ¿Cómo está, mi estimada? Buenos días. ¿Me podría, por favor, brindar su nombre completo, un número de DNI y el último monto facturado de su servicio, por favor?', 'start': 79.74, 'end': 91.36, 'no_speech_prob': 0.0, 'avg_logprob': -0.18627450746648452, 'compression_ratio': 1.2}, {'text': 'Ya, yo soy, mi nombre es Angélica Mamana Coyo.', 'start': 91.36, 'end': 95.86, 'no_speech_prob': 0.0, 'avg_logprob': -0.42961164701332166, 'compression_ratio': 1.3383838383838385}, {'text': 'Ya, en Medellín es 45573706.', 'start': 96.64, 'end': 103.36, 'no_speech_prob': 0.0, 'avg_logprob': -0.42961164701332166, 'compression_ratio': 1.3383838383838385}, {'text': 'Ok, el último monto que se ha realizado el pago o el último monto facturado de sus servicios?', 'start': 103.7, 'end': 109.1, 'no_speech_prob': 0.0, 'avg_logprob': -0.42961164701332166, 'compression_ratio': 1.3383838383838385}, {'text': 'Sí, ahorita 2990.', 'start': 109.68, 'end': 111.36, 'no_speech_prob': 0.0, 'avg_logprob': -0.42961164701332166, 'compression_ratio': 1.3383838383838385}, {'text': '2990.', 'start': 112.34, 'end': 113.26, 'no_speech_prob': 0.0, 'avg_logprob': -0.42961164701332166, 'compression_ratio': 1.3383838383838385}, {'text': 'Está bien.', 'start': 113.78, 'end': 114.16, 'no_speech_prob': 0.0, 'avg_logprob': -0.42961164701332166, 'compression_ratio': 1.3383838383838385}, {'text': 'Eso no es que realiza del pago.', 'start': 114.5, 'end': 116.54, 'no_speech_prob': 0.0, 'avg_logprob': -0.42961164701332166, 'compression_ratio': 1.3383838383838385}, {'text': 'Ahorita han cancelado.', 'start': 117.08, 'end': 118.8, 'no_speech_prob': 0.0, 'avg_logprob': -0.42961164701332166, 'compression_ratio': 1.3383838383838385}, {'text': 'Bueno, ahorita ha pagado, claro, ha pagado el día de hoy y ha pagado 30 con 10, no 25.90. ¿Cuánto?', 'start': 118.8, 'e ...
# 2026-01-10 05:59:50,121 - INFO - Diarización desactivada por el usuario.
# 2026-01-10 05:59:50,121 - INFO - Combinando transcripción con speakers...
# Guardando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155042371100001731 998811016 41398045 MASIVO_MOVIL KONECTA 1006_transcription.json
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155042371100001731 998811016 41398045 MASIVO_MOVIL KONECTA 1006_transcription.json
# Completado: 9155042371100001731 998811016 41398045 MASIVO_MOVIL KONECTA 1006.wav
#   - Calidad: 89.8%
#   - Speakers: 1
#   - Duracion: 263.5s
#
# ============================================================
# Procesando 9/50: 9155042433790001731 945668019 43191453 MASIVO_MOVIL KONECTA 1006 _1.wav
# ============================================================
# 2026-01-10 05:59:50,124 - INFO - Preprocesando audio...
# Audio cargado exitosamente: 9155042433790001731 945668019 43191453 MASIVO_MOVIL KONECTA 1006 _1.wav (339.1s, 8000Hz)
# 2026-01-10 05:59:50,369 - INFO - Aplicando filtro paso banda...
# 2026-01-10 05:59:53,477 - INFO - Eliminando tonos de espera...
# 2026-01-10 05:59:53,657 - INFO - Eliminando silencios...
# 2026-01-10 05:59:56,171 - INFO - Exportando para Whisper...
# 2026-01-10 05:59:56,198 - INFO - Audio exportado exitosamente con pydub: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155042433790001731 945668019 43191453 MASIVO_MOVIL KONECTA 1006 _1.wav
# ...
# Completado: 9155103738420001731 900983834 71464723 1706 ABAI _1.wav
#   - Calidad: 88.0%
#   - Speakers: 1
#   - Duracion: 211.0s
#
# ============================================================
# Procesando 48/50: 9155104197160001731 999469275 75379493 1706 GSS _1.wav
# ============================================================
# 2026-01-10 06:20:13,535 - INFO - Preprocesando audio...
# Audio cargado exitosamente: 9155104197160001731 999469275 75379493 1706 GSS _1.wav (257.5s, 8000Hz)
# 2026-01-10 06:20:13,744 - INFO - Aplicando filtro paso banda...
# 2026-01-10 06:20:16,010 - INFO - Eliminando tonos de espera...
# 2026-01-10 06:20:16,143 - INFO - Eliminando silencios...
# 2026-01-10 06:20:17,982 - INFO - Exportando para Whisper...
# 2026-01-10 06:20:18,000 - INFO - Audio exportado exitosamente con pydub: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155104197160001731 999469275 75379493 1706 GSS _1.wav
# 2026-01-10 06:20:18,000 - INFO - Iniciando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9155104197160001731 999469275 75379493 1706 GSS _1.wav
# Audio cargado exitosamente: temp_9155104197160001731 999469275 75379493 1706 GSS _1.wav (197.0s, 16000Hz)
# 2026-01-10 06:20:18,015 - INFO - Processing audio with duration 03:16.975
# 2026-01-10 06:20:18,290 - INFO - VAD filter removed 02:15.727 of audio
# 2026-01-10 06:20:20,485 - INFO - Transcripción completada para {'language': 'es', 'duration': 196.975, 'segments': [{'text': 'Bienvenido a Movistar, te habla Bexabeluna. Dígame, ¿qué te puedo ayudar?', 'start': 0.18, 'end': 4.18, 'no_speech_prob': 0.0, 'avg_logprob': -0.22965377955127964, 'compression_ratio': 1.4787234042553192}, {'text': 'Sabe qué, señorita Bexabel, tengo un problema con el internet. Varios días que no tengo internet y estoy bien incómoda.', 'start': 4.18, 'end': 10.18, 'no_speech_prob': 0.0, 'avg_logprob': -0.22965377955127964, 'compression_ratio': 1.4787234042553192}, {'text
18, 'no_speech_prob': 0.0, 'avg_logprob': -0.4713068146597255, 'compression_ratio': 1.464}, {'text': 'Llamé a tu compañera y me dijo que le iba a rescatear y no sé qué dónde.', 'start': 15.18, 'end': 22.18, 'no_speech_prob': 0.0, 'avg_logprob': -0.4713068146597255, 'compression_ratio': 1.464}, {'text': 'De ustedes me dijo para apagarlo por cinco minutos, lo apagué y otra vez lo defendí pero igual sigue el problema.', 'start': 22.18, 'end': 29.74, 'no_speech_prob': 0.0, 'avg_logprob': -0.4713068146597255, 'compression_ratio': 1.464}, {'text': '¿Es el número del teléfono cual le llama?', 'start': 29.74, 'end': 31.3, 'no_speech_prob': 0.0, 'avg_logprob': -0.27630538710310487, 'compression_ratio': 1.6354166666666667}, {'text': 'Sí, amigo, ese es el número.', 'start': 31.78, 'end': 32.78, 'no_speech_prob': 0.0, 'avg_logprob': -0.27630538710310487, 'compression_ratio': 1.6354166666666667}, {'text': 'Bien, permíteme un momento por favor que estarían verificando en el sistema.', 'start': 33.26, 'end': 37.06, 'no_speech_prob': 0.0, 'avg_logprob': -0.27630538710310487, 'compression_ratio': 1.6354166666666667}, {'text': 'Dame unos segundos.', 'start': 37.4, 'end': 38.1, 'no_speech_prob': 0.0, 'avg_logprob': -0.27630538710310487, 'compression_ratio': 1.6354166666666667}, {'text': 'Ya veo.', 'start': 39.07, 'end': 39.39, 'no_speech_prob': 0.0, 'avg_logprob': -0.27630538710310487, 'compression_ratio': 1.6354166666666667}, {'text': 'Un momento.', 'start': 39.83, 'end': 40.45, 'no_speech_prob': 0.0, 'avg_logprob': -0.27630538710310487, 'compression_ratio': 1.6354166666666667}, {'text': 'Ok.', 'start': 40.97, 'end': 41.25, 'no_speech_prob': 0.0, 'avg_logprob': -0.27630538710310487, 'compression_ratio': 1.6354166666666667}, {'text': '¿Su nombre me dijo cuál es?', 'start': 41.73, 'end': 42.95, 'no_speech_prob': 0.0, 'avg_logprob': -0.27630538710310487, 'compression_ratio': 1.6354166666666667}, {'text': 'Este es el número de mi mamá, Gladys Rengijo Flores.', 'start': 43.31, 'end': 45.97, 'no_speech_prob': 0.0, 'avg_logprob': -0.27630538710310487, 'compression_ratio': 1.6354166666666667}, {'text': 'No, el nombre es de usted.', 'start': 46.39, 'end': 47.57, 'no_speech_prob': 0.0, 'avg_logprob': -0.27630538710310487, 'compression_ratio': 1.6354166666666667}, {'text': 'De mí es Paul, pero el número que te estoy llamando es la línea de mi mamá.', 'start': 48.05, 'end': 53.43, 'no_speech_prob': 0.0, 'avg_logprob': -0.27630538710310487, 'compression_ratio': 1.6354166666666667}, {'text': 'No, claro, entiendo Paul, pero para poderme dirigir a usted.', 'start': 53.85, 'end': 56.79, 'no_speech_prob': 0.0, 'avg_logprob': -0.27630538710310487, 'compression_ratio': 1.6354166666666667}, {'text': 'Ah, ya, Paul, Paul.', 'start': 57.57, 'end': 59.23, 'no_speech_prob': 0.0, 'avg_logprob': -0.27630538710310487, 'compression_ratio': 1.6354166666666667}, {'text': 'Bien, Paul. A ver, permíteme un momento, voy a verificar si la configuración que te han realizado antes ha sido realizada de manera correcta. Dame un momento.', 'start': 59.77, 'end': 68.61, 'no_speech_prob': 0.0, 'avg_logprob': -0.2335227288983085, 'compression_ratio': 1.2907801418439717}, {'text': 'Ya veo.', 'start': 69.54, 'end': 69.92, 'no_speech_prob': 0.0, 'avg_logprob': -0.2335227288983085, 'compression_ratio': 1.2907801418439717}, {'text': 'Sí, gracias.', 'start': 70.3, 'end': 70.96, 'no_speech_prob': 0.0, 'avg_logprob': -0.233522 ...
# 2026-01-10 06:20:40,069 - INFO - Diarización desactivada por el usuario.
# 2026-01-10 06:20:40,069 - INFO - Combinando transcripción con speakers...
# Guardando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155104542620011731 900983834 70902440 1706 ABAI_transcription.json
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155104542620011731 900983834 70902440 1706 ABAI_transcription.json
# Completado: 9155104542620011731 900983834 70902440 1706 ABAI.wav
#   - Calidad: 87.1%
#   - Speakers: 1
#   - Duracion: 523.0s
#
# ============================================================
# Procesando 50/50: 9155104640990001731 999469275 77031172 1706 KONECTA.wav
# ============================================================
# 2026-01-10 06:20:40,071 - INFO - Preprocesando audio...
# Audio cargado exitosamente: 9155104640990001731 999469275 77031172 1706 KONECTA.wav (606.7s, 8000Hz)
# 2026-01-10 06:20:40,474 - INFO - Aplicando filtro paso banda...
# 2026-01-10 06:21:12,365 - INFO - Eliminando tonos de espera...
# 2026-01-10 06:21:12,684 - INFO - Eliminando silencios...
# 2026-01-10 06:21:17,092 - INFO - Exportando para Whisper...
# 2026-01-10 06:21:17,134 - INFO - Audio exportado exitosamente con pydub: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\audioPro\temp_9
todo lo correspondiente. De acuerdo a ello le estaríamos informando qué estaríamos realizando. ¿Listo?', 'start': 70.25, 'end': 81.77, 'no_speech_prob': 0.0, 'avg_logprob': -0.2073412761092186, 'compression_ratio': 1.5606060606060606}, {'text': 'Sí, por favor no se demore señorita porque hace un rato llamé y me han tenido un ratazo esperando y la verdad es que estoy incómoda porque ya varios días que no tengo internet pero sin embargo Movistar sigue cobrando a pesar de que no tengo internet. Entonces eso me incomoda. Y usted puede ver ahí que yo no tengo ni una deuda con ustedes. Entonces por favor quiero que me pierda rápido.', 'start': 81.77, 'end': 99.25, 'no_sp ...
# 2026-01-10 06:21:33,045 - INFO - Diarización desactivada por el usuario.
# 2026-01-10 06:21:33,046 - INFO - Combinando transcripción con speakers...
# Guardando transcripción: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155104640990001731 999469275 77031172 1706 KONECTA_transcription.json
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155104640990001731 999469275 77031172 1706 KONECTA_transcription.json
# Completado: 9155104640990001731 999469275 77031172 1706 KONECTA.wav
#   - Calidad: 89.5%
#   - Speakers: 1
#   - Duracion: 606.7s
#
# ============================================================
# Procesamiento completado: 50/50 exitosos
# ============================================================
#
# ✓ Transcripciones completadas: 50

# %%
# OPCIÓN B: Solo Diarización (Diferida)
print("Iniciando SOLO DIARIZACIÓN basada en transcripción previa...\n")
if 'transcription_results' in locals() and transcription_results:
    transcription_results = transcription_agent.add_diarization_to_results(
        results=transcription_results
    )
    print(f"\n Diarización completada para {len(transcription_results)} audios")
else:
    print("Error: No se encontraron resultados de transcripción. Por favor, ejecuta la OPCIÓN A primero.")
# Out:
# Iniciando SOLO DIARIZACIÓN basada en transcripción previa...
#
# Usando audio procesado encontrado en audioPro: temp_9155033267980001731 999799232 70942859 MASIVO_MOVIL ABAI 0906 _1.wav
#
# --- Iniciando diarización para: 9155033267980001731 999799232 70942859 MASIVO_MOVIL ABAI 0906 _1.wav ---
# 2026-01-10 06:24:23,063 - INFO - Diarización completada en 170.01s
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155033267980001731 999799232 70942859 MASIVO_MOVIL ABAI 0906 _1_transcription.json
# ✓ Diarización completada para 9155033267980001731 999799232 70942859 MASIVO_MOVIL ABAI 0906 _1.wav
# Usando audio procesado encontrado en audioPro: temp_9155033327270001731 999799232 75316202 MASIVO_MOVIL ABAI 0906.wav
#
# --- Iniciando diarización para: 9155033327270001731 999799232 75316202 MASIVO_MOVIL ABAI 0906.wav ---
# 2026-01-10 06:26:12,479 - INFO - Diarización completada en 109.41s
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155033327270001731 999799232 75316202 MASIVO_MOVIL ABAI 0906_transcription.json
# ✓ Diarización completada para 9155033327270001731 999799232 75316202 MASIVO_MOVIL ABAI 0906.wav
# Usando audio procesado encontrado en audioPro: temp_9155034794510001731 945206356 09337147 MASIVO_MOVIL GSS 0906 _1.wav
#
# --- Iniciando diarización para: 9155034794510001731 945206356 09337147 MASIVO_MOVIL GSS 0906 _1.wav ---
# 2026-01-10 06:27:54,747 - INFO - Diarización completada en 102.27s
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155034794510001731 945206356 09337147 MASIVO_MOVIL GSS 0906 _1_transcription.json
# ✓ Diarización completada para 9155034794510001731 945206356 09337147 MASIVO_MOVIL GSS 0906 _1.wav
# Usando audio procesado encontrado en audioPro: temp_9155036654930001731 945206356 72467112 MASIVO_MOVIL KONECTA 0906.wav
#
# --- Iniciando diarización para: 9155036654930001731 945206356 72467112 MASIVO_MOVIL KONECTA 0906.wav ---
# 2026-01-10 06:30:54,933 - INFO - Diarización completada en 180.18s
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155036654930001731 945206356 72467112 MASIVO_MOVIL KONECTA 0906_transcription.json
# ✓ Diarización completada para 9155036654930001731 945206356 72467112 MASIVO_MOVIL KONECTA 0906.wav
# Usando audio procesado encontrado en audioPro: temp_9155041036900001731 964061323 72396494 MASIVO_MOVIL ABAI 1006 _1.wav
#
# --- Iniciando diarización para: 9155041036900001731 964061323 72396494 MASIVO_MOVIL ABAI 1006 _1.wav ---
# 2026-01-10 06:33:22,087 - INFO - Diarización completada en 147.15s
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155041036900001731 964061323 72396494 MASIVO_MOVIL ABAI 1006 _1_transcription.json
# ✓ Diarización completada para 9155041036900001731 964061323 72396494 MASIVO_MOVIL ABAI 1006 _1.wav
# Usando audio procesado encontrado en audioPro: temp_9155041370430001731 964061323 48576957 MASIVO_MOVIL ABAI 1006.wav
#
# --- Iniciando diarización para: 9155041370430001731 964061323 48576957 MASIVO_MOVIL ABAI 1006.wav ---
# 2026-01-10 06:38:11,767 - INFO - Diarización completada en 289.68s
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155041370430001731 964061323 48576957 MASIVO_MOVIL ABAI 1006_transcription.json
# ✓ Diarización completada para 9155041370430001731 964061323 48576957 MASIVO_MOVIL ABAI 1006.wav
# Usando audio procesado encontrado en audioPro: temp_9155042319270001731 998811016 74812275 MASIVO_MOVIL KONECTA 1006 _1.wav
#
# --- Iniciando diarización para: 9155042319270001731 998811016 74812275 MASIVO_MOVIL KONECTA 1006 _1.wav ---
# 2026-01-10 06:39:26,432 - INFO - Diarización completada en 74.66s
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155042319270001731 998811016 74812275 MASIVO_MOVIL KONECTA 1006 _1_transcription.json
# ✓ Diarización completada para 9155042319270001731 998811016 74812275 MASIVO_MOVIL KONECTA 1006 _1.wav
# Usando audio procesado encontrado en audioPro: temp_9155042371100001731 998811016 41398045 MASIVO_MOVIL KONECTA 1006.wav
#
# --- Iniciando diarización para: 9155042371100001731 998811016 41398045 MASIVO_MOVIL KONECTA 1006.wav ---
# 2026-01-10 06:40:54,078 - INFO - Diarización completada en 87.64s
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155042371100001731 998811016 41398045 MASIVO_MOVIL KONECTA 1

# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155104542620011731 900983834 70902440 1706 ABAI_transcription.json
# ✓ Diarización completada para 9155104542620011731 900983834 70902440 1706 ABAI.wav
# Usando audio procesado encontrado en audioPro: temp_9155104640990001731 999469275 77031172 1706 KONECTA.wav
#
# --- Iniciando diarización para: 9155104640990001731 999469275 77031172 1706 KONECTA.wav ---
# 2026-01-10 08:44:55,739 - INFO - Diarización completada en 240.52s
# Transcripción guardada en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions\9155104640990001731 999469275 77031172 1706 KONECTA_transcription.json
# ✓ Diarización completada para 9155104640990001731 999469275 77031172 1706 KONECTA.wav
#
#  Diarización completada para 50 audios

# %% [markdown]
# ## 📈 Visualización de Métricas de Transcripción (Audio → Texto)
#
# Esta sección muestra métricas del proceso de transcripción:
# - Calidad de transcripción (quality scores)
# - Confianza del modelo Whisper
# - Eficiencia de procesamiento
# - Efectividad del preprocesamiento
# - Análisis de speakers

# %%
# Importar módulo de visualización
from visualize_transcription_metrics import generate_all_visualizations

print("📊 Generando visualizaciones de métricas de transcripción...\n")

# Generar todas las visualizaciones
figures, df_trans = generate_all_visualizations(str(config.TRANSCRIPTION_DIR))
# Out:
# 📊 Generando visualizaciones de métricas de transcripción...
#
# Cargando metricas de 50 transcripciones...
# Cargadas 50 transcripciones exitosamente
#
# Generando visualizaciones interactivas...
# 7 visualizaciones generadas

# %% [markdown]
# ### 📊 Dashboard Resumen

# %%
# Mostrar dashboard con KPIs
if 'dashboard' in figures:
    figures['dashboard'].show()
else:
    print("⚠️ No hay datos de transcripción para visualizar")

# %% [markdown]
# ### 📊 Distribución de Calidad

# %%
# Distribución de quality scores
if 'quality_distribution' in figures:
    figures['quality_distribution'].show()

# %% [markdown]
# ### 🎯 Confianza del Modelo

# %%
# Scores de confianza por archivo
if 'confidence_scores' in figures:
    figures['confidence_scores'].show()

# %% [markdown]
# ### 📈 Duración vs Calidad

# %%
# Relación entre duración y calidad
if 'duration_vs_quality' in figures:
    figures['duration_vs_quality'].show()

# %% [markdown]
# ### ⚡ Eficiencia de Procesamiento

# %%
# Tiempo de procesamiento y ratio de tiempo real
if 'processing_efficiency' in figures:
    figures['processing_efficiency'].show()

# %% [markdown]
# ### 🔧 Efectividad del Preprocesamiento

# %%
# Métricas de preprocesamiento: silencio removido, tonos de espera, etc.
if 'preprocessing_effectiveness' in figures:
    figures['preprocessing_effectiveness'].show()

# %% [markdown]
# ### 👥 Análisis de Speakers

# %%
# Distribución y tiempo por speaker
if 'speaker_analysis' in figures:
    figures['speaker_analysis'].show()

# %% [markdown]
# ### 📋 Tabla de Datos

# %%
# Mostrar tabla con métricas
if not df_trans.empty:
    print("\n📊 Métricas de Transcripción:\n")
    display(df_trans[[
        'archivo', 'quality_score', 'avg_confidence', 
        'audio_duration', 'processing_time', 'num_speakers'
    ]].head(10))
    
    # Exportar a CSV
    trans_report_path = config.OUTPUT_DIR / "reporte_transcripcion_metricas.csv"
    df_trans.to_csv(trans_report_path, index=False, encoding='utf-8-sig')
    print(f"\n✅ Reporte de transcripción exportado a: {trans_report_path}")
# Out:
# 📊 Métricas de Transcripción:
#                                              archivo  quality_score  \
# 0  9155033267980001731 999799232 70942859 MASIVO_...          89.84
# 1  9155033327270001731 999799232 75316202 MASIVO_...          91.02
# 2  9155034794510001731 945206356 09337147 MASIVO_...          88.16
# 3  9155036654930001731 945206356 72467112 MASIVO_...          86.95
# 4  9155041036900001731 964061323 72396494 MASIVO_...          86.53
# 5  9155041370430001731 964061323 48576957 MASIVO_...          93.37
# 6  9155042319270001731 998811016 74812275 MASIVO_...          90.96
# 7  9155042371100001731 998811016 41398045 MASIVO_...          89.76
# 8  9155042433790001731 945668019 43191453 MASIVO_...          93.02
# 9  9155042582490001731 945668019 70088919 MASIVO_...          92.33
#
#    avg_confidence  audio_duration  processing_time  num_speakers
# 0             1.0          422.94       188.486930             2
# 1             1.0          250.86       118.006780             2
# 2             1.0          457.32       115.342643             2
# 3             1.0          558.54       204.468517             2
# 4             1.0          452.97       170.626613             2
# 5             1.0          824.43       366.443508             3
# 6             1.0          162.60        82.812665             2
# 7             1.0          263.46        99.202674             2
# 8             1.0          339.09       151.470197             2
# 9             1.0          491.94       206.604542             2
# ✅ Reporte de transcripción exportado a: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\reporte_transcripcion_metricas.csv

# %% [markdown]
# ## 4. 🤖 Agente de Auditoría de Calidad de Servicio al Cliente
#
# Este agente:
# - **Usa el LLM** para analizar si el asesor cumple con las reglas
# - Verifica cumplimiento con criterios JSON
# - Genera reporte de compliance con scores detallados

# %% [markdown]
# ### 4.1. Verificación de Conexión con LLM
#
# **IMPORTANTE**: Esta celda verifica que el LLM (LM Studio) esté funcionando correctamente antes de procesar.

# %%
# Importar librerías necesarias
import sys
import json
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')

# Configurar estilo de gráficos
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# Importar módulos del proyecto
import config
#from agents.transcription_agent import TranscriptionAgent
from agents.greeting_agent import GreetingAgent, QualityAgent
#from agents.audio_processor import AudioProcessor

print("✓ Librerías importadas correctamente")
print(f"✓ Directorio de transcripciones: {config.TRANSCRIPTION_DIR}")
print(f"✓ Directorio de salida: {config.OUTPUT_DIR}")
# Out:
# ✓ Librerías importadas correctamente
# ✓ Directorio de transcripciones: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\transcriptions
# ✓ Directorio de salida: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output

# %%
# Verificar configuración del LLM
print("="*60)
print("VERIFICACIÓN DE CONFIGURACIÓN LLM")
print("="*60)
print(f"\n Configuración:")
print(f"  - Base URL: {config.OPENAI_BASE_URL}")
print(f"  - Modelo: {config.GPT_MODEL}")
print(f"  - API Key configurada: {'Sí' if config.OPENAI_API_KEY else 'No'}")

# Probar conexión
from openai import OpenAI

try:
    print(f"\n Probando conexión con LM Studio...", end=" ")
    test_client = OpenAI(
        api_key=config.OPENAI_API_KEY,
        base_url=config.OPENAI_BASE_URL
    )
    
    response = test_client.chat.completions.create(
        model=config.GPT_MODEL,
        messages=[
            {"role": "system", "content": "Responde brevemente."},
            {"role": "user", "content": "Di 'OK' si funciona."}
        ],
        temperature=0.1,
        max_tokens=10
    )
    
    print(" CONEXIÓN EXITOSA")
    print(f"  - Respuesta: {response.choices[0].message.content}")
    if hasattr(response, 'usage'):
        print(f"  - Tokens usados: {response.usage.total_tokens}")
    print(f"\n El LLM está funcionando correctamente. Puedes continuar con el análisis.")
    
except Exception as e:
    print(" ERROR")
    print(f"\n No se pudo conectar con el LLM: {str(e)}")
    print(f"\n Soluciones:")
    print(f"  1. Verifica que LM Studio esté ejecutándose")
    print(f"  2. Confirma que el servidor esté en {config.OPENAI_BASE_URL}")
    print(f"  3. Asegúrate de que el modelo {config.GPT_MODEL} esté cargado")
    print(f"\n El análisis continuará pero usará reglas básicas en lugar del LLM")

# %%
# Definir modelos y sus URLs a comparar
MODELS_TO_COMPARE = [
    
    {
        "model": "qwen3-8b", 
        "url": "http://localhost:1234/v1", 
        "name": "Qwen-Local"
    },
    {
        "model": "meta-llama-3-8b-instruct", 
        "url": "http://localhost:1234/v1", 
        "name": "Llama-Local"
    },
    # Puedes agregar más modelos aquí, incluso de APIs remotas
    # {
    #     "model": "gpt-4o", 
    #     "url": "https://api.openai.com/v1", 
    #     "name": "OpenAI-Cloud"
    # }
]

all_results = {}
print(f"✓ {len(MODELS_TO_COMPARE)} configuraciones de modelos listas para comparación")
# Out:
# ✓ 2 configuraciones de modelos listas para comparación

# %%
print(f"Iniciando análisis comparativo con {len(MODELS_TO_COMPARE)} configuraciones de LLM")

for config_item in MODELS_TO_COMPARE:
    model = config_item["model"]
    url = config_item["url"]
    display_name = config_item["name"]
    
    print(f"\n{'#'*60}")
    print(f"PROCESANDO CON: {display_name} ({model})")
    print(f"URL: {url}")
    print(f"{'#'*60}")
    
    # Inicializar agente con el modelo y URL específicos
    agent = QualityAgent(
        criteria_path=str(config.CRITERIOS_JSON),
        use_ai=True,
        model_name=model,
        base_url=url
    )
    
    results = agent.process_directory(
        transcription_dir=str(config.TRANSCRIPTION_DIR),
        output_dir=str(config.GREETING_DIR)
    )
    # Guardar resultados usando el nombre amigable o el modelo como clave
    all_results[display_name] = results
sleep(30)
print("\n✓ Procesamiento multi-modelo y multi-URL completado")
# Out:
# Iniciando análisis comparativo con 2 configuraciones de LLM
#
# ############################################################
# PROCESANDO CON: Qwen-Local (qwen3-8b)
# URL: http://localhost:1234/v1
# ############################################################
# Agente configurado con LangChain
#    - Modelo: qwen3-8b
#    - Base URL: http://localhost:1234/v1
#    Probando conexion con LLM... Conexion exitosa (LangChain)
# Encontrados 50 archivos de transcripción
#
# ============================================================
# Analizando 1/50: 9155033267980001731 999799232 70942859 MASIVO_MOVIL ABAI 0906 _1_transcription.json
# ============================================================
#
# Evaluando 10 reglas en una sola llamada al LLM...
#    Llamando al LLM con LangChain (qwen3-8b)... Respuesta recibida
#    Analisis completado
# Análisis guardado en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\greeting_analysis\9155033267980001731 999799232 70942859 MASIVO_MOVIL ABAI 0906 _1_transcription_qwen3-8b_quality_analysis.json
# Completado: 9155033267980001731 999799232 70942859 MASIVO_MOVIL ABAI 0906 _1_transcription.json
#   - Modelo: qwen3-8b
#   - Score Global: 100.0/100
#
# ============================================================
# Analizando 2/50: 9155033327270001731 999799232 75316202 MASIVO_MOVIL ABAI 0906_transcription.json
# ============================================================
#
# Evaluando 10 reglas en una sola llamada al LLM...
#    Llamando al LLM con LangChain (qwen3-8b)... Respuesta recibida
#    Analisis completado
# Análisis guardado en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\greeting_analysis\9155033327270001731 999799232 75316202 MASIVO_MOVIL ABAI 0906_transcription_qwen3-8b_quality_analysis.json
# Completado: 9155033327270001731 999799232 75316202 MASIVO_MOVIL ABAI 0906_transcription.json
#   - Modelo: qwen3-8b
#   - Score Global: 91.0/100
#
# ============================================================
# Analizando 3/50: 9155034794510001731 945206356 09337147 MASIVO_MOVIL GSS 0906 _1_transcription.json
# ============================================================
#
# Evaluando 10 reglas en una sola llamada al LLM...
#    Llamando al LLM con LangChain (qwen3-8b)... Respuesta recibida
#    Analisis completado
# Análisis guardado en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\greeting_analysis\9155034794510001731 945206356 09337147 MASIVO_MOVIL GSS 0906 _1_transcription_qwen3-8b_quality_analysis.json
# Completado: 9155034794510001731 945206356 09337147 MASIVO_MOVIL GSS 0906 _1_transcription.json
#   - Modelo: qwen3-8b
#   - Score Global: 97.0/100
#
# ============================================================
# Analizando 4/50: 9155036654930001731 945206356 72467112 MASIVO_MOVIL KONECTA 0906_transcription.json
# ============================================================
#
# Evaluando 10 reglas en una sola llamada al LLM...
#    Llamando al LLM con LangChain (qwen3-8b)... Respuesta recibida
#    Analisis completado
# Análisis guardado en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\greeting_analysis\9155036654930001731 945206356 72467112 MASIVO_MOVIL KONECTA 0906_transcription_qwen3-8b_quality_analysis.json
# Completado: 9155036654930001731 945206356 72467112 MASIVO_MOVIL KONECTA 0906_transcription.json
#   - Modelo: qwen3-8b
#   - Score Global: 95.5/100
#
# ============================================================
# Analizando 5/50: 9155041036900001731 964061323 72396494 MASIVO_MOVIL ABAI 1006 _1_transcription.json
# ============================================================
#
# Evaluando 10 reglas en una sola llamada al LLM...
#    Llamando al LLM con LangChain (qwen3-8b)... Respuesta recibida
#    Analisis completado
# Análisis guardado en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\greeting_analysis\9155041036900001731 964061323 72396494 MASIVO_MOVIL ABAI 1006 _1_transcription_qwen3-8b_quality_analysis.json
# Completado: 9155041036900001731 964061323 72396494 MASIVO_MOVIL ABAI 1006 _1_transcription.json
#   - Modelo: qwen3-8b
#   - Score Global: 89.5/100
#
# ============================================================
# Analizando 6/50: 9155041370430001731 964061323 48576957 MASIVO_MOVIL ABAI 1006_transcription.json
# ============================================================
#
# Evaluando 10 reglas en una sola llamada al LLM...
#    Llamando al LLM con LangChain (qwen3-8b)... Respuesta recibida
#    Analisis completado
# Análisis guardado en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\greeting_analysis\9155041370430001731 964061323 48576957 MASIVO_MOVIL ABAI 1006_transcription_qwen3-8b_quality_analysis.json
# Completado: 9155041370430001731 964061323 48576957 MASIVO_MOVIL ABAI 1006_transcription.json
#   - Modelo: qwen3-8b
#   - Score Global: 97.5/100
#
# ============================================================
# Analizando 7/50: 9155042319270001731 998811016 74812275 MASIVO_MOVIL KONECTA 1006 _1_transcription.json
# ============================================================
#
# Evaluando 10 reglas en una sola llamada al LLM...
#    Llamando al LLM con LangChain (qwen3-8b)... Respuesta recibida
#    Analisis completado
# Análisis guardado en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\greeting_analysis\9155042319270001731 998811016 74812275 MASIVO_MOVIL KONECTA 1006 _1_transcription_qwen3-8b_quality_analysis.json
# Completado: 9155042319270001731 998811016 74812275 MASIVO_MOVIL KONECTA 1006 _1_transcription.json
#   - Modelo: qwen3-8b
#   - Score Global: 100.0/100
#
# ============================================================
# Analizando 8/50: 9155042371100001731 998811016 41398045 MASIVO_MOVIL KONECTA 1006_transcription.json
# ============================================================
#
# Evaluando 10 reglas en una sola llamada al LLM...
#    Llamando al LLM con LangChain (qwen3-8b)... Respuesta recibida
#    Analisis completado
# Análisis guardado en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\greeting_analysis\9155042371100001731 998811016 41398045 MASIVO_MOVIL KONECTA 1006_transcription_qwen3-8b_quality_analysis.json
# Completado: 9155042371100001731 998811016 41398045 MASIVO_MOVIL KONECTA 1006_transcription.json
#   - Modelo: qwen3-8b
#   - Score Global: 95.5/100
#
# ============================================================
# Analizando 9/50: 9155042433790001731 945668019 43191453 MASIVO_MOVIL KONECTA 1006 _1_transcription.json
# ============================================================
#
# Evaluando 10 reglas en una sola llamada al LLM...
#    Llamando al LLM con LangChain (qwen3-8b)... Respuesta recibida
#    Analisis completado
# Análisis guardado en: d:\Proy\AntiG\MIA\NLP\TrabajoFinal\output\greeting_analysis\9155042433790001731 945668019 43191453 MASIVO_MOVIL KONECTA 1006 _1_transcription_qwen3-8b_quality_analysis.json
# Completado: 9155042433790001731 945668019 43191453 MASIVO_MOVIL KONECTA 1006 _1_transcription.json
#   - Modelo: qwen3-8b
#   - Score Global: 97.5/100
#
# ============================================================
# Analizando 10/50: 9155042582490001731 945668019 70088919 MASIVO_MOVIL GSS 1006_transcription.json
# ============================================================
#
# Evaluando 10 reglas en una sola llamada al LLM...
#    Llamando al LLM con LangChain (qwen3-8b)...

# %%
# Mostrar resumen de análisis
if greeting_results:
    print("\n" + "="*80)
    print("RESUMEN DE ANÁLISIS DE CALIDAD")
    print("="*80)
    
    for i, result in enumerate(greeting_results[:5], 1):  # Mostrar primeros 5
        print(f"\n{i}. {result['audio_file']}")
        print(f"   Score Global: {result['global_score']}/100")
        print(f"   Cumplimiento: {result['compliance']['global_result']}")
        
        rules = result['rule_analysis']
        
        # Mostrar reglas clave
        r1 = rules.get('R1_validacion_datos', {})
        r2 = rules.get('R2_empatia_claridad', {})
        
        print(f"\n   ✓ R1 Validación/Identificación: {'CUMPLE' if r1.get('cumple') else 'NO CUMPLE'} (Score: {r1.get('score', 0)}/100)")
        print(f"   ✓ R2 Empatía/Saludo: {'CUMPLE' if r2.get('cumple') else 'NO CUMPLE'} (Score: {r2.get('score', 0)}/100)")
        
        # Mostrar evidencia del LLM
        if r2.get('evidencia'):
            print(f"   📝 Evidencia LLM: {r2.get('evidencia')[:100]}...")
    
    if len(greeting_results) > 5:
        print(f"\n... y {len(greeting_results) - 5} análisis más.")
else:
    print("⚠️ No hay resultados de análisis")

# %% [markdown]
# ## 5. 📊 Visualización de Métricas

# %%
# Preparar datos para visualización
if greeting_results:
    greeting_data = []
    for result in greeting_results:
        rules = result['rule_analysis']
        greeting_data.append({
            'Audio': result['audio_file'][:30],  # Truncar nombre
            'Cumplimiento': result['compliance']['global_result'],
            'Puntuación': result['global_score'],
            'R1_Score': rules.get('R1_validacion_datos', {}).get('score', 0),
            'R2_Score': rules.get('R2_empatia_claridad', {}).get('score', 0),
            'R3_Score': rules.get('R3_ofertas_adecuadas', {}).get('score', 0),
            'R4_Score': rules.get('R4_respeto_decision', {}).get('score', 0),
            'R5_Score': rules.get('R5_formalizacion_cierre', {}).get('score', 0)
        })
    
    df_greeting = pd.DataFrame(greeting_data)
    print("✓ Datos preparados para visualización")
    print(f"\n📊 Estadísticas generales:")
    print(f"  - Puntuación promedio: {df_greeting['Puntuación'].mean():.1f}/100")
    print(f"  - Tasa de cumplimiento: {(df_greeting['Cumplimiento'] == 'CUMPLE').sum()}/{len(df_greeting)} ({(df_greeting['Cumplimiento'] == 'CUMPLE').sum()/len(df_greeting)*100:.1f}%)")
else:
    print("⚠️ No hay datos para visualizar")

# %%
# Gráfico: Distribución de Puntuaciones
if greeting_results:
    fig = go.Figure()
    
    colors = ['green' if score >= 80 else 'orange' if score >= 60 else 'red' 
              for score in df_greeting['Puntuación']]
    
    fig.add_trace(go.Bar(
        x=df_greeting['Audio'],
        y=df_greeting['Puntuación'],
        marker_color=colors,
        text=df_greeting['Puntuación'],
        texttemplate='%{text:.0f}',
        textposition='outside'
    ))
    
    fig.add_hline(y=80, line_dash="dash", line_color="green", 
                  annotation_text="Umbral CUMPLE (80)")
    
    fig.update_layout(
        title='Puntuación Global de Calidad por Audio (Analizado con LLM)',
        xaxis_title='Audio',
        yaxis_title='Puntuación',
        height=500,
        showlegend=False
    )
    
    fig.show()

# %%
# Gráfico: Scores por Regla (Heatmap)
if greeting_results:
    score_cols = ['R1_Score', 'R2_Score', 'R3_Score', 'R4_Score', 'R5_Score']
    
    fig = go.Figure(data=go.Heatmap(
        z=df_greeting[score_cols].values,
        x=['R1: Validación', 'R2: Empatía', 'R3: Ofertas', 'R4: Respeto', 'R5: Cierre'],
        y=df_greeting['Audio'],
        colorscale='RdYlGn',
        text=df_greeting[score_cols].values,
        texttemplate='%{text:.0f}',
        textfont={"size": 10},
        colorbar=dict(title="Score")
    ))
    
    fig.update_layout(
        title='Scores por Regla (Evaluación LLM)',
        xaxis_title='Regla',
        yaxis_title='Audio',
        height=max(400, len(df_greeting) * 25)
    )
    
    fig.show()

# %% [markdown]
# ## 6. 💾 Exportar Resultados

# %%
# Exportar a CSV
if greeting_results:
    report_path = config.OUTPUT_DIR / "reporte_calidad_llm.csv"
    df_greeting.to_csv(report_path, index=False, encoding='utf-8-sig')
    print(f"✅ Reporte exportado a: {report_path}")
    
    # Mostrar tabla
    display(df_greeting)

# %%
import pandas as pd
import plotly.express as px

# 1. Extraer datos para comparación
comparison_data = []
for config_name, results in all_results.items():
    for res in results:
        comparison_data.append({
            "Config": config_name,
            "Audio": res['audio_file'][:30], # Truncar para visualización
            "Score": res['global_score'],
            "Compliance": res['compliance']['global_result']
        })

if comparison_data:
    df_comp = pd.DataFrame(comparison_data)

    # 2. Gráfico de Barras Comparativo
    fig = px.bar(df_comp, x="Audio", y="Score", color="Config", barmode="group",
                 title="Comparación de Scores Globales por Configuración de LLM",
                 labels={"Score": "Puntuación (0-100)", "Audio": "Archivo de Audio", "Config": "Configuración"})
    fig.show()

    # 3. Resumen Promedio por Configuración
    avg_scores = df_comp.groupby("Config")["Score"].mean().reset_index()
    fig_avg = px.pie(avg_scores, values="Score", names="Config", 
                     title="Distribución de Calidad Promedio por Configuración")
    fig_avg.show()

    print("Resumen Comparativo:")
    display(avg_scores)
else:
    print("⚠️ No hay datos para comparar")
